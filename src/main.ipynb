# %% [markdown]
# # Student dropout analysis for increasing retension

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading data from csv file

# %%
df = pd.read_csv('../dataset/education_dropout.csv')

# %% [markdown]
# ### print first five raws of the dataset

# %%
df.head(20)
# Out:
#       student_id  age      gender first_generation_college  \
# 0   STU_00000001   23        Male                       No
# 1   STU_00000002   20        Male                      Yes
# 2   STU_00000003   19      Female                       No
# 3   STU_00000004   17        Male                       No
# 4   STU_00000005   17        Male                      Yes
# 5   STU_00000006   22      Female                       No
# 6   STU_00000007   17      Female                       No
# 7   STU_00000008   18      Female                       No
# 8   STU_00000009   17        Male                       No
# 9   STU_00000010   17        Male                       No
# 10  STU_00000011   24        Male                       No
# 11  STU_00000012   21      Female                      Yes
# 12  STU_00000013   21  Non-binary                       No
# 13  STU_00000014   17      Female                       No
# 14  STU_00000015   20        Male                       No
# ...

# %%
df.isnull().sum()
# Out:
# student_id                             0
# age                                    0
# gender                                 0
# first_generation_college               0
# international_student                  0
# residency_status                       0
# high_school_gpa                        0
# sat_score                            750
# act_score                              0
# advanced_courses_taken                 0
# extracurricular_activities             0
# major                                  0
# enrollment_status                      0
# semester_credits                       0
# admission_type                         0
# starting_semester                      0
# family_income                          0
# financial_aid_received                 0
# pell_grant_eligible (scholarship)      0
# student_loan_amount                    0
# has_campus_job                         0
# current_gpa                          750
# credits_completed                      0
# ...

# %%
df.dtypes
# Out:
# student_id                               str
# age                                    int64
# gender                                   str
# first_generation_college                 str
# international_student                    str
# residency_status                         str
# high_school_gpa                      float64
# sat_score                            float64
# act_score                              int64
# advanced_courses_taken                 int64
# extracurricular_activities             int64
# major                                    str
# enrollment_status                        str
# semester_credits                       int64
# admission_type                           str
# starting_semester                        str
# family_income                            str
# financial_aid_received                   str
# pell_grant_eligible (scholarship)        str
# student_loan_amount                    int64
# has_campus_job                           str
# ...

# %%
df.shape
# Out:
# (15000, 36)

# %%
df.nunique()
# Out:
# student_id                           15000
# age                                     15
# gender                                   3
# first_generation_college                 2
# international_student                    2
# residency_status                         3
# high_school_gpa                        201
# sat_score                              760
# act_score                               21
# advanced_courses_taken                  12
# extracurricular_activities              11
# major                                    7
# enrollment_status                        2
# semester_credits                         6
# admission_type                           3
# starting_semester                        3
# family_income                            4
# financial_aid_received                   2
# pell_grant_eligible (scholarship)        2
# student_loan_amount                  11947
# has_campus_job                           2
# current_gpa                            331
# ...

# %%
df = df.

# %%
cols_to_fix = ['first_generation_college', 'international_student', 'enrollment_status', 'financial_aid_received', 'pell_grant_eligible (scholarship)', 'has_disability', 'dropped_out']
