# %% [markdown]
# ### Importing required packages

# %%
import sys
sys.path.append('..')

import pandas as pd
from scipy.stats import chi2_contingency

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Loading the final dataset

# %%
df = pd.read_csv('../data/final_data/final_data.csv')
df.head()
# Out:
#    student_id  age  gender  first_generation_college  international_student  \
# 0           1   23    Male                     False                  False
# 1           2   20    Male                      True                  False
# 2           3   19  Female                     False                  False
# 3           4   17    Male                     False                   True
# 4           5   17    Male                      True                   True
#
#   residency_status  high_school_gpa  sat_score  act_score  \
# 0         In-state             2.88     1034.0         26
# 1         In-state             2.79     1162.0         20
# 2         In-state             3.44     1264.0         22
# 3         In-state             2.86      966.0         28
# 4     Out-of-state             3.77     1174.0         25
#
#    advanced_courses_taken  extracurricular_activities            major  \
# 0                       2                           2  Health Sciences
# ...

# %% [markdown]
# ## Chi-Square Test for Independence between Academic Risk and Dropped Out

# %%
# Create contingency table
contingency_table = pd.crosstab(df['academic_risk'], df['dropped_out'])
print("Contingency Table:")
print(contingency_table)

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"\nChi-Square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)

# Interpretation
alpha = 0.05
if p < alpha:
    print(f"\nSince p-value ({p}) < alpha ({alpha}), we reject the null hypothesis.")
    print("There is a significant association between academic_risk and dropped_out.")
else:
    print(f"\nSince p-value ({p}) >= alpha ({alpha}), we fail to reject the null hypothesis.")
    print("There is no significant association between academic_risk and dropped_out.")
# Out:
# Contingency Table:
# dropped_out    False  True
# academic_risk
# False           3700   1394
# True            6022   3884
#
# Chi-Square Statistic: 206.37571844469304
# P-value: 8.484249241176815e-47
# Degrees of Freedom: 1
# Expected Frequencies:
# [[3301.5912 1792.4088]
#  [6420.4088 3485.5912]]
#
# Since p-value (8.484249241176815e-47) < alpha (0.05), we reject the null hypothesis.
# There is a significant association between academic_risk and dropped_out.

# %% [markdown]
# ## Chi-Square Test for Independence between Financial Risk and Dropped Out

# %%
# Create contingency table for financial_risk
contingency_table_fin = pd.crosstab(df['financial_risk'], df['dropped_out'])
print("Contingency Table for Financial Risk:")
print(contingency_table_fin)

# Perform Chi-Square test
chi2_fin, p_fin, dof_fin, expected_fin = chi2_contingency(contingency_table_fin)

print(f"\nChi-Square Statistic: {chi2_fin}")
print(f"P-value: {p_fin}")
print(f"Degrees of Freedom: {dof_fin}")
print("Expected Frequencies:")
print(expected_fin)

# Interpretation
if p_fin < alpha:
    print(f"\nSince p-value ({p_fin}) < alpha ({alpha}), we reject the null hypothesis.")
    print("There is a significant association between financial_risk and dropped_out.")
else:
    print(f"\nSince p-value ({p_fin}) >= alpha ({alpha}), we fail to reject the null hypothesis.")
    print("There is no significant association between financial_risk and dropped_out.")
# Out:
# Contingency Table for Financial Risk:
# dropped_out     False  True
# financial_risk
# False            5532   2949
# True             4190   2329
#
# Chi-Square Statistic: 1.4308989413450692
# P-value: 0.23161778681133416
# Degrees of Freedom: 1
# Expected Frequencies:
# [[5496.8188 2984.1812]
#  [4225.1812 2293.8188]]
#
# Since p-value (0.23161778681133416) >= alpha (0.05), we fail to reject the null hypothesis.
# There is no significant association between financial_risk and dropped_out.
